# %%
path = '/media/sunao/新加卷/host/json/chinese_only.json'
#open(path).readline()
import json
movie = [json.loads(line) for line in open(path)]
movie[0]
# Out:
# {'_id': {'$oid': '5a6e8ce4826103a610726a1b'},
#  'rating': {'max': 10, 'average': 6.5, 'stars': '35', 'min': 0},
#  'reviews_count': 944,
#  'wish_count': 30940,
#  'douban_site': '',
#  'year': '2014',
#  'images': {'small': 'https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2187231762.jpg',
#   'large': 'https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2187231762.jpg',
#   'medium': 'https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2187231762.jpg'},
#  'alt': 'https://movie.douban.com/subject/7054604/',
#  'id': '7054604',
#  'mobile_url': 'https://movie.douban.com/subject/7054604/mobile',
#  'title': '变形金刚4：绝迹重生',
#  'do_count': None,
#  'share_url': 'https://m.douban.com/movie/subject/7054604',
#  'seasons_count': None,
#  'schedule_url': '',
#  'episodes_count': None,
#  'countries': ['美国', '中国大陆'],
#  'genres': ['动作', '科幻'],
#  'collect_count': 228116,
#  'casts': [{'alt': 'https://movie.douban.com/celebrity/1035674/',
# ...

# %%
import pandas as pd
from pandas import DataFrame
movie = DataFrame(movie)
movie
# Out:
#                                         _id  ...   year
# 0      {'$oid': '5a6e8ce4826103a610726a1b'}  ...   2014
# 1      {'$oid': '5a6e8d0d826103a610726a36'}  ...   2015
# 2      {'$oid': '5a6e8d6d826103a610726a54'}  ...   2008
# 3      {'$oid': '5a6e8d75826103a610726a5c'}  ...   2006
# 4      {'$oid': '5a6e8d90826103a610726a68'}  ...   2004
# 5      {'$oid': '5a6e8d99826103a610726a6d'}  ...   2008
# 6      {'$oid': '5a6e8da2826103a610726a77'}  ...   2000
# 7      {'$oid': '5a6e8daa826103a610726a7a'}  ...   1994
# 8      {'$oid': '5a6e8dba826103a610726a85'}  ...   2004
# 9      {'$oid': '5a6e8dfe826103a610726a9c'}  ...   2010
# 10     {'$oid': '5a6e8e00826103a610726a9f'}  ...   2013
# 11     {'$oid': '5a6e8e05826103a610726aa3'}  ...   1994
# 12     {'$oid': '5a6e8e0b826103a610726ab3'}  ...   2008
# 13     {'$oid': '5a6e8e0f826103a610726abb'}  ...   2014
# 14     {'$oid': '5a6e8e15826103a610726ad1'}  ...   2010
# 15     {'$oid': '5a6e8e16826103a610726ad5'}  ...   2014
# ...
